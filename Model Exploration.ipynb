# %% [markdown]
# <a href="https://colab.research.google.com/github/milesfking/NBA-Champion-Model/blob/main/New%20Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import GridSearchCV, cross_validate
from sklearn.linear_model import LogisticRegression, LinearRegression, Ridge
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ## Data Cleaning

# %%
# Load in dataset of previous seasons, include only teams who made the playoffs
dataset = pd.read_csv('nba_team_advanced_data.csv')
dataset = dataset[dataset["Playoffs"] == "Y"]

# Load in dataset of previous seasons, include only teams who made the playoffs
test_dataset = pd.read_csv('2023_advanced_data.csv')
test_dataset = test_dataset[test_dataset["Playoffs"] == "Y"]

# Drop irrelevant columns
dataset = dataset.drop(columns=['Playoffs', 'Losing_season', 'Arena', 'L', 'W', 'PW', 'PL', 'Attend.'])
test_dataset = test_dataset.drop(columns=['Playoffs', 'Losing_season', 'Arena', 'L', 'W', 'PW', 'PL', 'Attend.'])

# Split into predictor and response variables
X = dataset.iloc[:, ~ dataset.columns.isin(['Year', 'Champion', 'Team'])]
y = dataset.loc[:, dataset.columns == 'Champion'].values
y = np.array([0 if val == "N" else 1 for val in y])

X_test= test_dataset.iloc[:, ~ test_dataset.columns.isin(['Year', 'Champion', 'Team'])]
y_test = test_dataset.loc[:, test_dataset.columns == 'Champion'].values
y_test = np.array([0 if val == "N" else 1 for val in y_test])

# Transform data
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), ['won_last', 'won_last_3'])], remainder='passthrough')
X = np.array(ct.fit_transform(X))
X_test = np.array(ct.transform(X_test))

# Scale data
sc = StandardScaler()
X = sc.fit_transform(X)
X_test = sc.transform(X_test)

# %% [markdown]
# ## Decision Tree

# %%
# Create decision tree classifier
classifier = DecisionTreeClassifier()
classifier.fit(X, y)

param_grid= {'ccp_alpha': [0.1, 0.01, 0.001],
                         'criterion': ['gini', 'entropy'],
                         'max_depth': [5, 6, 7, 8, 9],
                         'max_features': ['auto', 'sqrt', 'log2']}

#Evaluate through K Fold (cv=10)
#N_jobs optional (how to run processors), -1 means to use all processors- optimizes
grid_search = GridSearchCV(estimator = classifier,
                           param_grid = param_grid,
                           scoring = 'f1',
                           cv = 10,
                           n_jobs = -1)

grid_search.fit(X, y)
best_accuracy = grid_search.best_score_
best_parameters = grid_search.best_params_
print("Best F1: {:.2f} %".format(best_accuracy*100))
print("Best Parameters:", best_parameters)

scoring = {'accuracy': 'accuracy',
           'precision': 'precision',
           'recall': 'recall',
           'f1': 'f1'}

optimized_classifier = DecisionTreeClassifier(criterion = 'gini',
                                              max_depth = 7,
                                              max_features = 'sqrt',
                                              ccp_alpha = 0.001,
                                              random_state = 0)

accuracies = cross_validate(estimator = optimized_classifier, X = X, y = y, cv = 10, scoring = scoring)

#https://stackoverflow.com/questions/51315083/convert-python-dict-of-arrays-into-a-dataframe
pd.DataFrame([k, *v] for k, v in accuracies.items())

y_pred = classifier.predict(X_test)
test_arrays = np.column_stack([test_dataset["Year"], test_dataset["Team"], y_pred.flatten()])
test_df = pd.DataFrame(test_arrays, columns = ['Year', 'Team', 'Prediction'])

# Return test dataframe
test_df
# Out:
# Best F1: 34.01 %
# Best Parameters: {'ccp_alpha': 0.001, 'criterion': 'gini', 'max_depth': 8, 'max_features': 'log2'}
#       Year                    Team Prediction
# 0   2023.0           Atlanta Hawks          0
# 1   2023.0          Boston Celtics          0
# 2   2023.0           Brooklyn Nets          0
# 3   2023.0           Chicago Bulls          0
# 4   2023.0     Cleveland Cavaliers          0
# 5   2023.0          Denver Nuggets          0
# 6   2023.0   Golden State Warriors          0
# 7   2023.0    Los Angeles Clippers          0
# 8   2023.0      Los Angeles Lakers          0
# 9   2023.0       Memphis Grizzlies          0
# 10  2023.0              Miami Heat          0
# 11  2023.0         Milwaukee Bucks          1
# 12  2023.0  Minnesota Timberwolves          0
# 13  2023.0    New Orleans Pelicans          0
# 14  2023.0         New York Knicks          0
# 15  2023.0   Oklahoma City Thunder          0
# 16  2023.0      Philadelphia 76ers          0
# 17  2023.0            Phoenix Suns          0
# 18  2023.0        Sacramento Kings          0
# 19  2023.0         Toronto Raptors          0

# %% [markdown]
# ## Logistic Regression

# %%
# Create logistic regression classifier
classifier = LogisticRegression(solver='lbfgs', random_state=0)
classifier.fit(X, y)

# Predict probabilities for test data
y_proba = classifier.predict_proba(X_test)

# Store predicted probabilities in DataFrame with team and year
team_names = test_dataset['Team'].values
year = test_dataset['Year'].values
predictions = pd.DataFrame(data=y_proba, columns=['Lose Probability', 'Win Probability'])
predictions.insert(loc=0, column='Team', value=team_names)
predictions.insert(loc=1, column='Year', value=year)

# Output DataFrame with team, year, and predicted probabilities
print("Model output:")
print(predictions.sort_values(by=['Win Probability'], ascending=False)[['Team', 'Win Probability']])

# Get the feature names after one-hot encoding
feature_names = ct.get_feature_names_out()

# Create a DataFrame to store coefficients and feature names
coefficients_df = pd.DataFrame({'Feature': feature_names, 'Coefficient': classifier.coef_.flatten()})

# Print the coefficients
print()
print("Model coefficients:")
print(coefficients_df)
# Out:
# Model output:
#                       Team  Win Probability
# 11         Milwaukee Bucks         0.130980
# 1           Boston Celtics         0.058115
# 6    Golden State Warriors         0.038805
# 5           Denver Nuggets         0.024476
# 4      Cleveland Cavaliers         0.014054
# 9        Memphis Grizzlies         0.012936
# 16      Philadelphia 76ers         0.008737
# 17            Phoenix Suns         0.006903
# 7     Los Angeles Clippers         0.004548
# 2            Brooklyn Nets         0.003390
# 14         New York Knicks         0.002499
# 3            Chicago Bulls         0.002490
# 18        Sacramento Kings         0.002434
# 8       Los Angeles Lakers         0.002137
# 13    New Orleans Pelicans         0.001919
# 12  Minnesota Timberwolves         0.001661
# 10              Miami Heat         0.001074
# 19         Toronto Raptors         0.001057
# 0            Atlanta Hawks         0.000752
# 15   Oklahoma City Thunder         0.000347
#
# Model coefficients:
#                   Feature  Coefficient
# 0     encoder__won_last_N    -0.163483
# 1     encoder__won_last_Y     0.163483
# 2   encoder__won_last_3_N     0.012740
# 3   encoder__won_last_3_Y    -0.012740
# 4          remainder__Age     0.515744
# 5          remainder__MOV     0.067769
# 6          remainder__SOS     0.025774
# 7          remainder__SRS     0.065914
# 8         remainder__ORtg     0.102944
# 9         remainder__DRtg    -0.168041
# 10        remainder__NRtg     0.330212
# 11        remainder__Pace     0.195973
# 12         remainder__FTr     0.426185
# 13        remainder__3PAr    -0.077681
# 14         remainder__TS%     0.014197
# 15       remainder__OeFG%     0.560192
# 16       remainder__OTOV%     0.063153
# 17        remainder__ORB%     0.462778
# 18     remainder__OFT/FGA    -0.895274
# 19       remainder__DeFG%    -0.503346
# 20       remainder__DTOV%     0.272734
# 21        remainder__DRB%     0.198100
# 22     remainder__DFT/FGA    -0.311749
# 23        remainder__W/L%     0.643843

# %% [markdown]
# ## Linear Regression and Softmax

# %%
# Create linear regression model
linear_regression = LinearRegression()
linear_regression.fit(X, y)

# Predict probabilities for test data
y_pred = linear_regression.predict(X_test)
y_prob = np.apply_along_axis(lambda x: np.exp(x) / np.sum(np.exp(x)), 0, y_pred)

# Store predicted probabilities in DataFrame with team and year
team_names = test_dataset['Team'].values
predictions = pd.DataFrame(data=y_prob, columns=['Win Probability'])

predictions.insert(loc=0, column='Team', value=team_names)

# Output DataFrame with team, year, and predicted probabilities
print("Model output:")
print(predictions.sort_values(by=['Win Probability'], ascending=False))

# Get the feature names after one-hot encoding
feature_names = ct.get_feature_names_out()

# Create a DataFrame to store coefficients and feature names
coefficients_df = pd.DataFrame({'Feature': feature_names, 'Coefficient': linear_regression.coef_.flatten()})

# Print the coefficients
print()
print("Model coefficients:")
print(coefficients_df)
# Out:
# Model output:
#                       Team  Win Probability
# 6    Golden State Warriors         0.064749
# 11         Milwaukee Bucks         0.056696
# 5           Denver Nuggets         0.054738
# 9        Memphis Grizzlies         0.054631
# 1           Boston Celtics         0.052027
# 17            Phoenix Suns         0.051623
# 4      Cleveland Cavaliers         0.051021
# 2            Brooklyn Nets         0.049259
# 8       Los Angeles Lakers         0.049067
# 3            Chicago Bulls         0.048306
# 14         New York Knicks         0.048117
# 16      Philadelphia 76ers         0.048117
# 7     Los Angeles Clippers         0.047930
# 0            Atlanta Hawks         0.047743
# 19         Toronto Raptors         0.047557
# 12  Minnesota Timberwolves         0.047371
# 18        Sacramento Kings         0.046274
# 13    New Orleans Pelicans         0.046094
# 15   Oklahoma City Thunder         0.045379
# 10              Miami Heat         0.043301
#
# Model coefficients:
#                   Feature   Coefficient
# 0     encoder__won_last_N  1.945607e+11
# 1     encoder__won_last_Y  1.945607e+11
# 2   encoder__won_last_3_N  2.949025e+11
# 3   encoder__won_last_3_Y  2.949025e+11
# 4          remainder__Age  1.421099e-02
# 5          remainder__MOV  4.228346e+00
# 6          remainder__SOS  5.490135e-01
# 7          remainder__SRS -4.440392e+00
# 8         remainder__ORtg -1.069462e+13
# 9         remainder__DRtg  1.039244e+13
# 10        remainder__NRtg  8.622648e+12
# 11        remainder__Pace  2.333273e-02
# 12         remainder__FTr  4.481896e-01
# 13        remainder__3PAr -2.561517e-02
# 14         remainder__TS%  8.695613e-01
# 15       remainder__OeFG% -9.383022e-01
# 16       remainder__OTOV%  4.397644e-02
# 17        remainder__ORB% -3.675902e-02
# 18     remainder__OFT/FGA -6.742516e-01
# 19       remainder__DeFG% -1.759148e-01
# 20       remainder__DTOV%  9.354496e-02
# 21        remainder__DRB%  7.827568e-02
# 22     remainder__DFT/FGA -4.393768e-02
# 23        remainder__W/L%  3.045654e-02

# %% [markdown]
# ## Ridge Regression and Softmax

# %%
# Create ridge regression model
ridge_regression = Ridge(alpha=1.0)
ridge_regression.fit(X, y)

# Predict probabilities for test data
y_pred = ridge_regression.predict(X_test)
y_prob = np.apply_along_axis(lambda x: np.exp(x) / np.sum(np.exp(x)), 0, y_pred)

# Store predicted probabilities in DataFrame with team and year
team_names = test_dataset['Team'].values
predictions = pd.DataFrame(data=y_prob, columns=['Win Probability'])

predictions.insert(loc=0, column='Team', value=team_names)

# Output dataframe with team, year, and predicted probabilities
print("Model output:")
print(predictions.sort_values(by=['Win Probability'], ascending=False))

# Get the feature names after one-hot encoding
feature_names = ct.get_feature_names_out()

# Create a DataFrame to store coefficients and feature names
coefficients_df = pd.DataFrame({'Feature': feature_names, 'Coefficient': ridge_regression.coef_.flatten()})

# Print the coefficients
print()
print("Model coefficients:")
print(coefficients_df)
# Out:
# Model output:
#                       Team  Win Probability
# 6    Golden State Warriors         0.062293
# 11         Milwaukee Bucks         0.057831
# 9        Memphis Grizzlies         0.053609
# 1           Boston Celtics         0.053209
# 5           Denver Nuggets         0.053133
# 4      Cleveland Cavaliers         0.052158
# 17            Phoenix Suns         0.050228
# 16      Philadelphia 76ers         0.049384
# 8       Los Angeles Lakers         0.048597
# 14         New York Knicks         0.048452
# 18        Sacramento Kings         0.048253
# 2            Brooklyn Nets         0.047992
# 3            Chicago Bulls         0.047773
# 7     Los Angeles Clippers         0.047586
# 12  Minnesota Timberwolves         0.047544
# 13    New Orleans Pelicans         0.047469
# 19         Toronto Raptors         0.047036
# 0            Atlanta Hawks         0.046771
# 15   Oklahoma City Thunder         0.045412
# 10              Miami Heat         0.045271
#
# Model coefficients:
#                   Feature  Coefficient
# 0     encoder__won_last_N    -0.020079
# 1     encoder__won_last_Y     0.020079
# 2   encoder__won_last_3_N    -0.006091
# 3   encoder__won_last_3_Y     0.006091
# 4          remainder__Age     0.013309
# 5          remainder__MOV    -0.053654
# 6          remainder__SOS     0.000935
# 7          remainder__SRS    -0.061669
# 8         remainder__ORtg     0.082768
# 9         remainder__DRtg     0.019879
# 10        remainder__NRtg     0.078698
# 11        remainder__Pace     0.019109
# 12         remainder__FTr     0.077455
# 13        remainder__3PAr    -0.011882
# 14         remainder__TS%     0.097495
# 15       remainder__OeFG%    -0.081605
# 16       remainder__OTOV%     0.002481
# 17        remainder__ORB%     0.014781
# 18     remainder__OFT/FGA    -0.124356
# 19       remainder__DeFG%    -0.111420
# 20       remainder__DTOV%     0.064384
# 21        remainder__DRB%     0.052574
# 22     remainder__DFT/FGA    -0.029233
# 23        remainder__W/L%     0.034343
